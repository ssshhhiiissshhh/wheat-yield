# %%
import rasterio
from rasterio.mask import mask
import fiona
import os
import numpy as np
import pandas as pd

# %%
def clip_raster_by_multiple_polygons(raster_path, geojson_path, output_dir):
    """
    Обрезает растровое изображение для каждого полигона в GeoJSON и сохраняет 
    каждый результат в отдельный файл.
    """
    # Убедитесь, что выходная директория существует
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
        print(f"Создана директория: {output_dir}")

    # 1. Загрузка всех геометрий из GeoJSON
    with fiona.open(geojson_path, "r") as shapefile:
        features = list(shapefile)
    
    print(f"Найдено полигонов для обрезки: {len(features)}")

    # 2. Открытие исходного растрового изображения (один раз)
    with rasterio.open(raster_path) as src:
        
        # 3. Итерация по каждому полигону (Feature) отдельно
        for i, feature in enumerate(features):
            geometry = [feature["geometry"]] # Оборачиваем геометрию в список для функции mask()
            
            # --- Шаг обрезки ---
            # Применяем маску только для текущего полигона
            try:
                out_image, out_transform = mask(src, geometry, crop=True, nodata=0)
            except ValueError as e:
                print(f"Пропущена обрезка полигона {i}: {e}")
                continue # Пропускаем полигоны, которые не пересекают растр
                
            # --- Подготовка метаданных для нового файла ---
            out_meta = src.meta.copy()
            out_meta.update({
                "driver": "GTiff",
                "height": out_image.shape[1], # Правильные размеры
                "width": out_image.shape[2],  # Правильные размеры
                "transform": out_transform,
                "nodata": 0 # Устанавливаем черный/прозрачный фон для областей вне полигона
            })

            # --- Сохранение файла ---
            output_filename = f"clipped_segment_{i:03d}.tif"
            output_path = os.path.join(output_dir, output_filename)
            
            with rasterio.open(output_path, "w", **out_meta) as dest:
                dest.write(out_image)
            
            print(f"  -> Сохранен файл: {output_path}")


def calculate_ndvi(red_band, nir_band):
    """
    Рассчитывает NDVI из массивов красного и ближнего инфракрасного каналов.
    """
    red_band = red_band.astype(float)
    nir_band = nir_band.astype(float)
    
    denominator = nir_band + red_band
    # Избегаем деления на ноль
    denominator[denominator == 0] = 1 

    ndvi = (nir_band - red_band) / denominator
    return ndvi

def load_and_process_ndvi_from_separate_files(rgb_path, ocn_path):
    """
    Загружает красный канал из RGB файла и NIR канал из OCN файла, 
    рассчитывает NDVI и сохраняет результат.

    :param rgb_path: Путь к файлу с каналами RGB.
    :param ocn_path: Путь к файлу с каналами OCN.
    :param output_path: Путь для сохранения карты NDVI.
    """
    
    # Предполагаемые индексы каналов (начинаются с 1):
    # RGB: 1=R, 2=G, 3=B. Мы берем КРАСНЫЙ канал (индекс 1).
    RED_BAND_INDEX = 1 
    # OCN: 1=O, 2=C, 3=Nir. Мы берем NIR канал (индекс 3).
    NIR_BAND_INDEX = 3 

    # 1. Загрузка Красного канала
    with rasterio.open(rgb_path) as src_rgb:
        red_band = src_rgb.read(RED_BAND_INDEX)
        # Метаданные берем из файла RGB, т.к. у него та же привязка, что и у OCN файла
        meta = src_rgb.meta.copy()

    # 2. Загрузка NIR канала
    with rasterio.open(ocn_path) as src_ocn:
        nir_band = src_ocn.read(NIR_BAND_INDEX)
    
    # Проверка на совпадение размеров изображений  
    if red_band.shape != nir_band.shape:  
        print(f"Размеры не совпадают: RGB={red_band.shape}, OCN={nir_band.shape}. Обрезаем...")
        
        # Определяем минимальные размеры
        min_height = min(red_band.shape[0], nir_band.shape[0])
        min_width = min(red_band.shape[1], nir_band.shape[1])
        
        # Обрезаем оба массива до общего размера
        red_band = red_band[:min_height, :min_width]
        nir_band = nir_band[:min_height, :min_width]

    # 3. Расчет NDVI
    ndvi_data = calculate_ndvi(red_band, nir_band)

    return np.nanmean(ndvi_data[ndvi_data != 0]) # Возвращаем среднее значение

# %%
# Сегментируем rgb изображение
clip_raster_by_multiple_polygons(
    raster_path="C:/Users/smolk/data/Field 2024/2024_07_03 Пшеница Выход в трубку - Колошение/rgb.tif",
    geojson_path="2024_выход_в_трубку-кущение_разметка.geojson",
    output_dir="output_segments_2024_выход_в_трубку-кущение" # Папка, куда будут сохранены все файлы
)
# Out:
# Найдено полигонов для обрезки: 148
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_000.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_001.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_002.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_003.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_004.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_005.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_006.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_007.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_008.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_009.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_010.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_011.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_012.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_013.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_014.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_015.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_016.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_017.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_018.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_019.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_020.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_021.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_022.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_023.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_024.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_025.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_026.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_027.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_028.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_029.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_030.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_031.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_032.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_033.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_034.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_035.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_036.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_037.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_038.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_039.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_040.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_041.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_042.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_043.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_044.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_045.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_046.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_047.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_048.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_049.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_050.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_051.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_052.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_053.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_054.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_055.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_056.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_057.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_058.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_059.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_060.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_061.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_062.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_063.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_064.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_065.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_066.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_067.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_068.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_069.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_070.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_071.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_072.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_073.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_074.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_075.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_076.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_077.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_078.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_079.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_080.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_081.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_082.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_083.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_084.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_085.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_086.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_087.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_088.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_089.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_090.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_091.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_092.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_093.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_094.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_095.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_096.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_097.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_098.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_099.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_100.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_101.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_102.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_103.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_104.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_105.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_106.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_107.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_108.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_109.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_110.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_111.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_112.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_113.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_114.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_115.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_116.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_117.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_118.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_119.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_120.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_121.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_122.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_123.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_124.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_125.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_126.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_127.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_128.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_129.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_130.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_131.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_132.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_133.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_134.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_135.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_136.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_137.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_138.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_139.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_140.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_141.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_142.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_143.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_144.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_145.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_146.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение\clipped_segment_147.tif

# %%
# Сегментируем ocn изображение
clip_raster_by_multiple_polygons(
    raster_path="C:/Users/smolk/data/Field 2024/2024_07_03 Пшеница Выход в трубку - Колошение/ocn.tif",
    geojson_path="2024_выход_в_трубку-кущение_разметка.geojson",
    output_dir="output_segments_2024_выход_в_трубку-кущение_NIR" # Папка, куда будут сохранены все файлы
)
# Out:
# Найдено полигонов для обрезки: 148
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_000.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_001.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_002.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_003.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_004.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_005.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_006.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_007.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_008.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_009.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_010.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_011.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_012.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_013.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_014.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_015.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_016.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_017.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_018.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_019.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_020.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_021.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_022.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_023.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_024.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_025.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_026.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_027.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_028.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_029.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_030.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_031.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_032.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_033.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_034.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_035.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_036.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_037.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_038.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_039.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_040.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_041.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_042.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_043.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_044.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_045.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_046.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_047.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_048.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_049.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_050.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_051.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_052.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_053.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_054.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_055.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_056.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_057.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_058.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_059.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_060.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_061.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_062.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_063.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_064.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_065.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_066.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_067.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_068.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_069.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_070.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_071.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_072.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_073.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_074.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_075.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_076.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_077.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_078.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_079.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_080.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_081.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_082.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_083.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_084.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_085.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_086.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_087.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_088.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_089.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_090.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_091.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_092.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_093.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_094.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_095.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_096.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_097.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_098.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_099.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_100.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_101.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_102.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_103.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_104.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_105.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_106.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_107.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_108.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_109.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_110.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_111.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_112.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_113.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_114.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_115.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_116.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_117.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_118.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_119.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_120.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_121.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_122.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_123.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_124.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_125.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_126.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_127.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_128.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_129.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_130.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_131.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_132.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_133.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_134.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_135.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_136.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_137.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_138.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_139.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_140.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_141.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_142.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_143.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_144.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_145.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_146.tif
#   -> Сохранен файл: output_segments_2024_выход_в_трубку-кущение_NIR\clipped_segment_147.tif

# %%
# --- Пример использования для одной пары файлов ---

# Вам нужно будет указать пути к вашим обрезанным файлам
mean_ndvi_value = load_and_process_ndvi_from_separate_files(
    rgb_path="output_segments_2024_выход_в_трубку-кущение/clipped_segment_000.tif",
    ocn_path="output_segments_2024_выход_в_трубку-кущение_NIR/clipped_segment_000.tif"
)

print(f"Среднее NDVI для делянки 000: {mean_ndvi_value:.4f}")
# Out:
# Среднее NDVI для делянки 000: 0.2784

# %%
import pandas as pd
import os

# Создаем датафрейм для результатов
df_ndvi = pd.DataFrame(columns=['plot_id', 'mean_ndvi'])

# Предполагаем, что файлы называются типа "segment_001.tif", "segment_002.tif" и т.д.
# И что есть парные RGB и NIR файлы с одинаковыми номерами

for i in range(0, 148):  # Предположим, что делянки от 1 до 147
    plot_id = f"{i:03d}"  # Форматируем номер как 001, 002, ...
    
    rgb_path = f"output_segments_2024_выход_в_трубку-кущение/clipped_segment_{plot_id}.tif"
    ocn_path = f"output_segments_2024_выход_в_трубку-кущение_NIR/clipped_segment_{plot_id}.tif"
    
    # Проверяем, что оба файла существуют
    if os.path.exists(rgb_path) and os.path.exists(ocn_path):
        try:
            # Используем вашу готовую функцию
            mean_ndvi = load_and_process_ndvi_from_separate_files(
                rgb_path=rgb_path,
                ocn_path=ocn_path
            )
            
            # Добавляем в датафрейм
            df_ndvi.loc[len(df_ndvi)] = [plot_id, mean_ndvi]
            print(f"Делянка {plot_id}: NDVI = {mean_ndvi:.4f}")
            
        except Exception as e:
            print(f"Ошибка при обработке делянки {plot_id}: {e}")
    else:
        print(f"Файлы для делянки {plot_id} не найдены")
# Out:
# Делянка 000: NDVI = 0.2784
# Делянка 001: NDVI = 0.2927
# Делянка 002: NDVI = 0.3316
# Делянка 003: NDVI = 0.3283
# Размеры не совпадают: RGB=(636, 1932), OCN=(636, 1933). Обрезаем...
# Делянка 004: NDVI = 0.3138
# Делянка 005: NDVI = 0.2846
# Делянка 006: NDVI = 0.3150
# Делянка 007: NDVI = 0.3071
# Делянка 008: NDVI = 0.3096
# Делянка 009: NDVI = 0.2733
# Делянка 010: NDVI = 0.2971
# Делянка 011: NDVI = 0.3176
# Делянка 012: NDVI = 0.2985
# Делянка 013: NDVI = 0.3024
# Делянка 014: NDVI = 0.3233
# Делянка 015: NDVI = 0.3125
# Делянка 016: NDVI = 0.3122
# Делянка 017: NDVI = 0.3340
# Делянка 018: NDVI = 0.3292
# Делянка 019: NDVI = 0.3146
# Делянка 020: NDVI = 0.2954
# Делянка 021: NDVI = 0.2768
# Делянка 022: NDVI = 0.3077
# Делянка 023: NDVI = 0.3092
# Делянка 024: NDVI = 0.3422
# Делянка 025: NDVI = 0.3252
# Делянка 026: NDVI = 0.3069
# Делянка 027: NDVI = 0.3039
# Делянка 028: NDVI = 0.3193
# Делянка 029: NDVI = 0.3400
# Делянка 030: NDVI = 0.3462
# Делянка 031: NDVI = 0.2891
# Делянка 032: NDVI = 0.2945
# Делянка 033: NDVI = 0.3269
# Делянка 034: NDVI = 0.3330
# Делянка 035: NDVI = 0.3400
# Делянка 036: NDVI = 0.3206
# Делянка 037: NDVI = 0.2914
# Делянка 038: NDVI = 0.3094
# Делянка 039: NDVI = 0.3103
# Делянка 040: NDVI = 0.3067
# Делянка 041: NDVI = 0.3189
# Делянка 042: NDVI = 0.2946
# Делянка 043: NDVI = 0.2928
# Делянка 044: NDVI = 0.2655
# Делянка 045: NDVI = 0.2437
# Делянка 046: NDVI = 0.2856
# Делянка 047: NDVI = 0.2759
# Делянка 048: NDVI = 0.2931
# Делянка 049: NDVI = 0.2794
# Делянка 050: NDVI = 0.2835
# Делянка 051: NDVI = 0.2978
# Делянка 052: NDVI = 0.2853
# Размеры не совпадают: RGB=(651, 1959), OCN=(651, 1958). Обрезаем...
# Делянка 053: NDVI = 0.2532
# Делянка 054: NDVI = 0.2802
# Делянка 055: NDVI = 0.2891
# Делянка 056: NDVI = 0.2959
# Делянка 057: NDVI = 0.3043
# Делянка 058: NDVI = 0.2977
# Делянка 059: NDVI = 0.2736
# Делянка 060: NDVI = 0.3223
# Делянка 061: NDVI = 0.3170
# Делянка 062: NDVI = 0.2940
# Делянка 063: NDVI = 0.2764
# Делянка 064: NDVI = 0.2956
# Делянка 065: NDVI = 0.2812
# Делянка 066: NDVI = 0.2468
# Делянка 067: NDVI = 0.2732
# Делянка 068: NDVI = 0.2652
# Делянка 069: NDVI = 0.2086
# Делянка 070: NDVI = 0.2559
# Делянка 071: NDVI = 0.2753
# Делянка 072: NDVI = 0.2897
# Делянка 073: NDVI = 0.2493
# Делянка 074: NDVI = 0.2782
# Делянка 075: NDVI = 0.2576
# Делянка 076: NDVI = 0.2774
# Размеры не совпадают: RGB=(632, 1953), OCN=(632, 1952). Обрезаем...
# Делянка 077: NDVI = 0.2961
# Делянка 078: NDVI = 0.2818
# Делянка 079: NDVI = 0.2771
# Делянка 080: NDVI = 0.3105
# Делянка 081: NDVI = 0.3221
# Делянка 082: NDVI = 0.2894
# Делянка 083: NDVI = 0.2907
# Делянка 084: NDVI = 0.2922
# Делянка 085: NDVI = 0.2888
# Делянка 086: NDVI = 0.2972
# Делянка 087: NDVI = 0.2860
# Делянка 088: NDVI = 0.2757
# Делянка 089: NDVI = 0.3220
# Делянка 090: NDVI = 0.3325
# Делянка 091: NDVI = 0.3160
# Делянка 092: NDVI = 0.2866
# Делянка 093: NDVI = 0.3045
# Делянка 094: NDVI = 0.2886
# Делянка 095: NDVI = 0.2771
# Делянка 096: NDVI = 0.2684
# Делянка 097: NDVI = 0.3026
# Делянка 098: NDVI = 0.3234
# Делянка 099: NDVI = 0.2679
# Делянка 100: NDVI = 0.2685
# Делянка 101: NDVI = 0.2836
# Делянка 102: NDVI = 0.2973
# Делянка 103: NDVI = 0.2799
# Делянка 104: NDVI = 0.2986
# Делянка 105: NDVI = 0.3060
# Делянка 106: NDVI = 0.3152
# Размеры не совпадают: RGB=(652, 1960), OCN=(652, 1959). Обрезаем...
# Делянка 107: NDVI = 0.2367
# Делянка 108: NDVI = 0.3195
# Делянка 109: NDVI = 0.3111
# Делянка 110: NDVI = 0.3142
# Делянка 111: NDVI = 0.2482
# Делянка 112: NDVI = 0.2443
# Делянка 113: NDVI = 0.2867
# Делянка 114: NDVI = 0.2823
# Делянка 115: NDVI = 0.2569
# Делянка 116: NDVI = 0.2448
# Делянка 117: NDVI = 0.2560
# Делянка 118: NDVI = 0.2710
# Делянка 119: NDVI = 0.2793
# Делянка 120: NDVI = 0.2772
# Делянка 121: NDVI = 0.2761
# Делянка 122: NDVI = 0.2932
# Делянка 123: NDVI = 0.2892
# Делянка 124: NDVI = 0.2892
# Делянка 125: NDVI = 0.2781
# Делянка 126: NDVI = 0.2804
# Делянка 127: NDVI = 0.2769
# Делянка 128: NDVI = 0.2810
# Делянка 129: NDVI = 0.3057
# Делянка 130: NDVI = 0.2787
# Делянка 131: NDVI = 0.2947
# Делянка 132: NDVI = 0.3020
# Делянка 133: NDVI = 0.3101
# Делянка 134: NDVI = 0.3178
# Делянка 135: NDVI = 0.2869
# Делянка 136: NDVI = 0.3142
# Делянка 137: NDVI = 0.3062
# Делянка 138: NDVI = 0.2899
# Делянка 139: NDVI = 0.2528
# Делянка 140: NDVI = 0.2787
# Делянка 141: NDVI = 0.2870
# Делянка 142: NDVI = 0.2767
# Делянка 143: NDVI = 0.2768
# Делянка 144: NDVI = 0.2719
# Делянка 145: NDVI = 0.2631
# Делянка 146: NDVI = 0.2821
# Делянка 147: NDVI = 0.2777

# %%
df_ndvi['genotype'] = None

# %%
df_ndvi = df_ndvi.astype({'plot_id': np.int16})

# %%
df_ndvi
# Out:
#      plot_id  mean_ndvi genotype
# 0          0   0.278411     None
# 1          1   0.292651     None
# 2          2   0.331634     None
# 3          3   0.328296     None
# 4          4   0.313839     None
# ..       ...        ...      ...
# 143      143   0.276801     None
# 144      144   0.271906     None
# 145      145   0.263052     None
# 146      146   0.282051     None
# 147      147   0.277735     None
#
# [148 rows x 3 columns]

# %%
for i in range(37):
    df_ndvi.iloc[i, 2] = i+1

# %%
df_ndvi.to_excel("df_ndvi.xlsx", index=False)
